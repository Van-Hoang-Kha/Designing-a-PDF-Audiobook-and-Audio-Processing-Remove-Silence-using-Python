# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    r'/home/kha/Documents/text-to-speech/Audio-Processing/Split-Audio/Results.csv')
df
# Out:
#                 Unnamed: 0              chunk1             chunk2  \
# 0          Amplitude(Peak)                 128                128
# 1            Amplitude(dB)   42.14419939295737  42.14419939295737
# 2          Amplitude(dBFS)                 0.0                0.0
# 3            Time duration            2.58 sec          0.256 sec
# 4              Frame Count             59340.0             5888.0
# 5  Total audio output time  155.39100000000002                NaN
#
#               chunk3             chunk4             chunk5             chunk6  \
# 0                128                128                128                128
# 1  42.14419939295737  42.14419939295737  42.14419939295737  42.14419939295737
# 2                0.0                0.0                0.0                0.0
# 3          2.294 sec          1.845 sec          0.258 sec          2.482 sec
# 4            52762.0            42435.0             5934.0            57086.0
# ...
